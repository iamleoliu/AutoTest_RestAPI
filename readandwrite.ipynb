# %%
import http.client
import json

conn = http.client.HTTPSConnection("192.168.68.157", 443)
payload = json.dumps({
  "encode": "text",
  "propertyReferences": [
    {
      "type": "analogValue",
      "instance": 1,
      "property": "presentValue",
      "priority": 8,
      "value": "70"
    }
  ]
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': '••••••',
  'Cookie': 'ECLYPSERESTSESSIONID=1ohr1f6hkfh5s1j75dki55t6hd'
}
conn.request("POST", "/api/rest/v1/protocols/bacnet/local/objects/write-property-multiple", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
